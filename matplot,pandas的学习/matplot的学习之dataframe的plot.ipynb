# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %%
matplotlib inline

# %%
df = DataFrame(np.random.randint(1,10,40).reshape(10,4),columns = ['A','B','C','D']) #reshape 重新组合 变成10行4列
df
# Out:
#    A  B  C  D
# 0  1  3  8  4
# 1  9  1  4  1
# 2  5  2  8  7
# 3  6  9  5  8
# 4  3  5  1  8
# 5  5  7  2  9
# 6  5  1  7  8
# 7  3  8  4  3
# 8  2  7  5  9
# 9  3  6  8  8

# %%
df.plot() #4条线分别代表了ABCD
# Out:
# <AxesSubplot:>

# %%
for i in df.index: 
    df.iloc[i].plot(label=str(i)) #对一个Series进行plot
plt.legend() #把图显示到图像上

# %%
df.plot(kind='barh') #kind的Bar会显示柱形图 h = horizion
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar',stacked='True') #stack可以是堆叠图
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area') #会显示整个区域
# Out:
# <AxesSubplot:>

# %%
df['A']
# Out:
# 0    1
# 1    9
# 2    5
# 3    6
# 4    3
# 5    5
# 6    5
# 7    3
# 8    2
# 9    3
# Name: A, dtype: int32
