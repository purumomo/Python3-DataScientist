# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
#复制到剪贴板

# %%
df = pd.read_clipboard()
df
# Out:
#     Position Programming Language Ratings
# 0         21                  SAS   0.69%
# 1         22                  Lua   0.61%
# 2         23                 Perl   0.57%
# 3         24              Fortran   0.57%
# 4         25                COBOL   0.54%
# 5         26      (Visual) FoxPro   0.49%
# 6         27                  Ada   0.48%
# 7         28               Kotlin   0.47%
# 8         29               Prolog   0.44%
# 9         30                 Lisp   0.38%
# 10        31           PowerShell   0.37%
# 11        32                Julia   0.36%
# 12        33               PL/SQL   0.34%
# 13        34                Scala   0.34%
# 14        35                 Dart   0.34%
# 15        36                    D   0.30%
# 16        37                 Logo   0.26%
# 17        38                  X++   0.25%
# 18        39                 ABAP   0.25%
# 19        40           TypeScript   0.24%
# 20        41                 Bash   0.23%
# ...

# %%
#转换成csv文件 在当前目录中创建文件
df.to_csv('df_io.csv',index=False)
# !more df_io.csv #直接打开文件

# %%
pd.read_csv('df_io.csv')
# Out:
#     Position Programming Language Ratings
# 0         21                  SAS   0.69%
# 1         22                  Lua   0.61%
# 2         23                 Perl   0.57%
# 3         24              Fortran   0.57%
# 4         25                COBOL   0.54%
# 5         26      (Visual) FoxPro   0.49%
# 6         27                  Ada   0.48%
# 7         28               Kotlin   0.47%
# 8         29               Prolog   0.44%
# 9         30                 Lisp   0.38%
# 10        31           PowerShell   0.37%
# 11        32                Julia   0.36%
# 12        33               PL/SQL   0.34%
# 13        34                Scala   0.34%
# 14        35                 Dart   0.34%
# 15        36                    D   0.30%
# 16        37                 Logo   0.26%
# 17        38                  X++   0.25%
# 18        39                 ABAP   0.25%
# 19        40           TypeScript   0.24%
# 20        41                 Bash   0.23%
# ...

# %%
#对于json的读写和操作
df_json = df.to_json()
pd.read_json(df_json)# 把json转化成dataFrame
# Out:
#     Position Programming Language Ratings
# 0         21                  SAS   0.69%
# 1         22                  Lua   0.61%
# 2         23                 Perl   0.57%
# 3         24              Fortran   0.57%
# 4         25                COBOL   0.54%
# 5         26      (Visual) FoxPro   0.49%
# 6         27                  Ada   0.48%
# 7         28               Kotlin   0.47%
# 8         29               Prolog   0.44%
# 9         30                 Lisp   0.38%
# 10        31           PowerShell   0.37%
# 11        32                Julia   0.36%
# 12        33               PL/SQL   0.34%
# 13        34                Scala   0.34%
# 14        35                 Dart   0.34%
# 15        36                    D   0.30%
# 16        37                 Logo   0.26%
# 17        38                  X++   0.25%
# 18        39                 ABAP   0.25%
# 19        40           TypeScript   0.24%
# 20        41                 Bash   0.23%
# ...

# %%
df.to_html('df_to.html')
