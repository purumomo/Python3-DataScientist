# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = [1,2,3]
b = [4,5,6]
plt.plot(a,b)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(a,b, '--') #改变Line图形样式

# %%
plt.plot(a,b, '*') #改变Line图形样式

# %%
c =[10,8,6]
d =[1,4,2]
plt.plot(a,b,'--',c,d,'*')
# Out:
# [<matplotlib.lines.Line2D at 0x188bbc02550>,
#  <matplotlib.lines.Line2D at 0x188bbc026a0>]

# %%
t = np.arange(0.0,2.0,0.1)
a = np.sin(t*np.pi)
plt.plot(t,s,'r--',label='aaaaa')
plt.plot(t*2,s,'b--',label='bbbb')
plt.xlabel('this is x')
plt.ylabel('this is y')
plt.title('this is a demo')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9872\2719099518.py in <module>
# ----> 1 t = np.arrange(0.0,2.0,0.1)
#       2 a = np.sin(t*np.pi)
#       3 plt.plot(t,s,'r--',label='aaaaa')
#       4 plt.plot(t*2,s,'b--',label='bbbb')
#       5 plt.xlabel('this is x')
#
# c:\Users\kaorukou ver2\anaconda4\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     311                 return Tester
#     312
# --> 313             raise AttributeError("module {!r} has no attribute "
#     314                                  "{!r}".format(__name__, attr))
#     315
#
# AttributeError: module 'numpy' has no attribute 'arrange'
