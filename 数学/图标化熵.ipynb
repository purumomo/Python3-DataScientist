# %%
import numpy as np
import matplotlib.pyplot as plt

#由于无法去取0的对数，因此将范围设为从0.01到0.99
x = np.linspace(0.01,0.99)
y = -x*np.log2(x) - (1-x)*np.log2(1-x)

#熵
plt.plot(x,y)
plt.xlabel("x",size = 14)
plt.ylabel("y",size = 14)
plt.grid()
plt.show()
